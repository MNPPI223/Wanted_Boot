# %% [markdown]
# # 07. Exception
# * Python 에서의 예외처리
# * AI 관련 서버에서 자주 발생하는 예외 케이스
# - 질문이 비어있음 ( Spring 백엔드에서 충분한 Filter 를 해주면 OK )
# - 존재하지 않거나 버전이 만료 된 모델
# - API 호출 실패 (API 키 만료, 초과 사용)
# - FileNotFound (RAG 시스템 구축 시 pdf, excel, sheet, csv) - Excel 위주로, pdf 리더(텍스트만 쫙 읽기)
# - 등의 파일을 I/O 답변 퀄리티를 높이게 되는데 이 때 file 관련
# - 에러가 많이 발생하게 된다.

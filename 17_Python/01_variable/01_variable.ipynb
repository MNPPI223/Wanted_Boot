# %% [markdown]
# ## 01. Python 변수
# * 변수란? 값을 담을 수 있는 공간이다.
# * Java 와는 다르게 Python 은 변수의 타입을 선언 시에 지정하지 않는다.
# * Python 은 런타임 시점에서 값을 보고 타입을 판단하게 된다.

# %% [markdown]
# # 02. 변수 이름 작성 규칙
# * Python 에서는 보통 변수명을 snake_case 로 작성을 한다.
# * Java 는 cammel_case 로 작성하게 된다.
# * userName <- Java
# * user_name <- python

# %%
user_question = "python 이 뭔가요?"

print(user_question)
# Out:
# python 이 뭔가요?

# %%
model_name = "stt-ai-model"
max_tokens = 1000
temperature = 0.7
is_streaming = True

print(model_name)
print(max_tokens)
print(temperature)
print(is_streaming)
# Out:
# stt-ai-model
# 1000
# 0.7
# True

# %% [markdown]
# ## Pytahon 의 자료형은 런타임 시 결정된다
# * type() 함수로 변수의 타입을 확인할 수 있다.

# %%
print(type(model_name))
print(type(max_tokens))
print(type(temperature))
print(type(is_streaming))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = "MNPPI"
user_question = "RAG 가 뭔가요?"

# MNPPI 의 질문 : RAG 가 뭐야?

print(name + " 의 질문 : " + user_question)

# f-string 방식

message = f"{name} 의 질문 : {user_question}"

print(message)
# Out:
# MNPPI 의 질문 : RAG 가 뭔가요?
# MNPPI 의 질문 : RAG 가 뭔가요?

# %% [markdown]
# ## 공부 Point
# * Java 와 비교하면서 어떤 부분이 Java 의 변수와 다른 것인가?
# * 변수의 선언과 할당이 무슨 차이가 있는가?

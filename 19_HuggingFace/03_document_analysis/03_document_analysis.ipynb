# %% [markdown]
# # 문서 분석 AI 기능 활용
#
# * PDF 파일을 Post 방식으로 전달
#     * 문서 분류 (어떤 카테고리의 문서인지 분류) ex> 스포츠, 금융, 인공지능
#     * 개체명 추출 (문서에서 중요 키워드 추출)
#     * 한국어로 문서 요약

# %%
# !pip install python-multipart pymupdf sentencepiece protobug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 3.2 MB/s  0:00:07 eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [protobug]2/4 [pymupdf]
# ...

# %% [markdown]
# # Hugging Face 를 해보는 이유
#
# * 이번 챕터에서는 아래 AI 기능을 구현할 것이다.
# - 감정 분석
# - 문서 분류
# - 문서 요약
# - 객체 추출
#
# * 이러한 기능을 직접 AI 모델을 만들고 학습시키는 것은
# 현실적으로 불가능하다.
# * 따라서 이미 학습 된 AI 모델을 가져와 서비스에 적용하는 것이
# 일반적인 개발 방식이라고 생각하면 된다.
# * AI 모델들과 DataSet 들이 모여진 Github 같은 사이트가 "HuggingFace"
# 라는 플랫폼이다.

# %% [markdown]
# # Hugging Face 를 활용하는 방법
# * 과거 방식
# - 모델 직접 학습
# - 모델 저장
# - 추론할 수 있는 코드 작성
#
# * Hugging Face 방식
# - 원하는 모델 검색
# - 모델을 다운로드
# - Python 코드 작성

# %% [markdown]
# # Transformers
#
# * Python 에서 AI model 을 쉽게 사용할 수 있도록 제공하는 라이브러리 이다.
# * 대표적으로 아래 기능들을 제공한다
#     * Pipline
#     * AutoTokenizer
#     * AutoModel
#     * AutoModelForSequenceClassification
#
# ---
# * Transformer
# - 트렌스포머는 자연어를 이해하기 위해 만들어진 딥러닝 모델 구조이다.
# - 현재 대부분의 LLM (GPT, Claude, Gemini) 과 NLP(LLM 을 깊게 들어가면 있는 것) 모델은
# - 트렌스포머 구조 기반으로 만들어져 있다.
#
# ---
#
# * AI Model 의 동작 방식
#
# - 문장 입력 -> Tokenizer -> 숫자로 변환 -> Transformer Model
# - -> 예측 -> 결과 반환

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 MB 10.4 MB/s  0:00:10m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 10.1 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 9.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 10.9 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 13.4 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.0 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 7.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 10.5 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.6/676.6 kB 9.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [transformers] [transformers]ub]
# ...
